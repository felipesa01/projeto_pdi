# %%
import pandas as pd
import geopandas as gpd
import numpy as np

import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

import matplotlib.pyplot as plt

import rasterio
from osgeo import gdal, ogr, osr
from gdalconst import *
gdal.UseExceptions()

from datetime import date
from datetime import datetime

import stac

# %% [markdown]
# ## Obter imagens da área de interesse via STAC (BrazilDataCube)

# %%
# Criar conexão com o servidor da STAC
bdc_stac_service = stac.STAC('http://brazildatacube.dpi.inpe.br/')

# Obter itens filtrados pelo objeto JSON (https://stacspec.org/STAC-api.html#operation/postSearchSTAC)
# Filtro: 200 primeiras imagens da coleção 'LC8SR-1' que intersectam o ponto (-46.872, -17.150).
item = bdc_stac_service.search({'collections':['LC8SR-1'], 
                                "intersects": {"type": "Point",
                                               "coordinates": [-46.872, -17.150]},
                                'limit': 200})

# Mostrar quantas imagens foram recuperadas
len(item.features)
# Out:
# 93

# %% [markdown]
# ## Criar um dicionário com as datas e links das imagens

# %%
links = {}

# Percorrer todos o itens obtidos ds STAC
for i in item.features:
    
    # Adquirir a data da imagem
    date = i['properties']['datetime'][0:10]
    
    # Inserir um item no dicionário 'links' com (chave = data da imagem) e (valor = URL da imagem).
    # IV selecionado: NDVI
    links[date] = i['assets']['sr_ndvi']['href']

# Mostrar dicionário de links
links
# Out:
# {'2020-08-26': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-08/220072/LC08_L1TP_220072_20200826_20200905_01_T1_sr_ndvi.tif',
#  '2020-08-10': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-08/220072/LC08_L1TP_220072_20200810_20200821_01_T1_sr_ndvi.tif',
#  '2020-07-25': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-07/220072/LC08_L1TP_220072_20200725_20200807_01_T1_sr_ndvi.tif',
#  '2020-07-09': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-07/220072/LC08_L1TP_220072_20200709_20200721_01_T1_sr_ndvi.tif',
#  '2020-06-23': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-06/220072/LC08_L1TP_220072_20200623_20200707_01_T1_sr_ndvi.tif',
#  '2020-06-07': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-06/220072/LC08_L1TP_220072_20200607_20200625_01_T1_sr_ndvi.tif',
#  '2020-05-22': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-05/220072/LC08_L1TP_220072_20200522_20200607_01_T1_sr_ndvi.tif',
#  '2020-05-06': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-05/220072/LC08_L1TP_220072_20200506_20200509_01_T1_sr_ndvi.tif',
#  '2020-04-20': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-04/220072/LC08_L1GT_220072_20200420_20200508_01_T2_sr_ndvi.tif',
#  '2020-04-04': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-04/220072/LC08_L1TP_220072_20200404_20200410_01_T1_sr_ndvi.tif',
#  '2020-03-19': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-03/220072/LC08_L1TP_220072_20200319_20200326_01_T1_sr_ndvi.tif',
#  '2020-03-03': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-03/220072/LC08_L1GT_220072_20200303_20200314_01_T2_sr_ndvi.tif',
#  '2020-02-16': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-02/220072/LC08_L1TP_220072_20200216_20200225_01_T1_sr_ndvi.tif',
#  '2020-01-31': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-01/220072/LC08_L1TP_220072_20200131_20200211_01_T1_sr_ndvi.tif',
#  '2020-01-15': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2020-01/220072/LC08_L1TP_220072_20200115_20200127_01_T1_sr_ndvi.tif',
#  '2019-12-30': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2019
 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-08/220072/LC08_L1TP_220072_20170818_20170826_01_T1_sr_ndvi.tif',
#  '2017-08-02': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-08/220072/LC08_L1TP_220072_20170802_20170812_01_T1_sr_ndvi.tif',
#  '2017-07-17': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-07/220072/LC08_L1TP_220072_20170717_20170727_01_T1_sr_ndvi.tif',
#  '2017-07-01': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-07/220072/LC08_L1TP_220072_20170701_20170715_01_T1_sr_ndvi.tif',
#  '2017-06-15': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-06/220072/LC08_L1TP_220072_20170615_20170629_01_T1_sr_ndvi.tif',
#  '2017-05-30': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-05/220072/LC08_L1TP_220072_20170530_20170615_01_T1_sr_ndvi.tif',
#  '2017-05-14': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-05/220072/LC08_L1TP_220072_20170514_20170525_01_T1_sr_ndvi.tif',
#  '2017-04-28': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-04/220072/LC08_L1GT_220072_20170428_20170515_01_T2_sr_ndvi.tif',
#  '2017-04-12': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-04/220072/LC08_L1TP_220072_20170412_20170501_01_T1_sr_ndvi.tif',
#  '2017-03-27': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-03/220072/LC08_L1TP_220072_20170327_20170414_01_T1_sr_ndvi.tif',
#  '2017-03-11': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-03/220072/LC08_L1TP_220072_20170311_20170317_01_T1_sr_ndvi.tif',
#  '2017-02-23': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-02/220072/LC08_L1TP_220072_20170223_20170301_01_T1_sr_ndvi.tif',
#  '2017-02-07': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-02/220072/LC08_L1TP_220072_20170207_20170216_01_T1_sr_ndvi.tif',
#  '2017-01-22': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-01/220072/LC08_L1TP_220072_20170122_20170311_01_T1_sr_ndvi.tif',
#  '2017-01-06': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2017-01/220072/LC08_L1TP_220072_20170106_20170312_01_T1_sr_ndvi.tif',
#  '2016-12-21': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-12/220072/LC08_L1TP_220072_20161221_20170315_01_T1_sr_ndvi.tif',
#  '2016-12-05': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-12/220072/LC08_L1GT_220072_20161205_20170317_01_T2_sr_ndvi.tif',
#  '2016-11-19': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-11/220072/LC08_L1TP_220072_20161119_20170318_01_T1_sr_ndvi.tif',
#  '2016-11-03': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-11/220072/LC08_L1TP_220072_20161103_20170318_01_T1_sr_ndvi.tif',
#  '2016-10-18': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-10/220072/LC08_L1TP_220072_20161018_20170319_01_T1_sr_ndvi.tif',
#  '2016-10-02': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-10/220072/LC08_L1TP_220072_20161002_20170320_01_T1_sr_ndvi.tif',
#  '2016-09-16': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-09/220072/LC08_L1TP_220072_20160916_20180528_01_T1_sr_ndvi.tif',
#  '2016-08-31': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-08/220072/LC08_L1TP_220072_20160831_20170321_01_T1_sr_ndvi.tif',
#  '2016-08-15': 'http://brazildatacube.dpi.inpe.br/Repository/Archive/LC8SR/2016-08/220072/LC08_L1TP_220072_20160815_20170322_01_T1_sr_ndvi.tif'}

# %% [markdown]
# ## Abrir arquivo de pontos e extrair coordenadas

# %%
# Abrir arquivo de pontos
df = gpd.read_file('./DADOS/pt_ref_23n.geojson')

# Gerar duas listas (lat e lon) com as coordenadas dos pontos
lat = []
lon = []
for i in df.geometry:
    lon.append(i.x)
    lat.append(i.y)

# %% [markdown]
# ## Amostrar os valores das imagens para os pontos de referência

# %%
# Para evitar a execução dessa célula, salvei o resultado dela (dicionário) em um arquivo. 
# Caso o arquivo seja encontrado, o processamento é evitado
try:
    out = np.load('./DADOS/out_ref.npy', allow_pickle=True).item()
    print("Arquivo aberto com sucesso!")
except:
    print("Arquivo não encontrado, amostrando pontos pela série de imagens...")
    
    # Criar um dicionário de saída
    out = {}
    # Percorrer todas os pares data(k)/URL(v) da lista 'links'
    for k,v in links.items():
        # Abrir a imagem da URL
        with rasterio.open(v) as src:
            # Obter o valores dos pixel da imagem para as coordenadas dos pontos (amostrar valores)
            val = [x for x in src.sample(zip(lon,lat))]

            # Transformar cada item (array unitario) da lista 'val' para número
            for i in range(len(val)):
                val[i] = val[i][0]

            # Inserir o item no dicionário 'out' com (chave = data da imagem) e (valor = lista de valores da imagem).
            out[k] = val
                    
    print("Amostragem finalizada!")
    
    try:
        np.save('./DADOS/out_ref.npy', out)
        print('O resultado foi salvo')
    except:
        print('O resultado não foi salvo')
# Out:
# Arquivo aberto com sucesso!

# %%
# Inserir os valores obtidos como colunas no dataframe dos pontos
for k,v in out.items():
    df.insert(loc=2,column=datetime.strptime(k,'%Y-%m-%d').date(), value=v)
    
df = df.drop(['operador','geometry','Name'],1)
df.rename(columns={'id': 'date'}, inplace=True)
df = df.set_index('date').T/10000

# %%
df
# Out:
# date            1       2       3       4       5       6       7       8   \
# 2016-08-15  0.3031  0.3617  0.2062  0.2176  0.3780  0.4199  0.7570  0.6181
# 2016-08-31  0.3376  0.8074  0.2434  0.6366  0.2110  0.4198  0.7434  0.6924
# 2016-09-16  0.1448  0.6675  0.2723  0.5561  0.3015  0.3332  0.5902  0.6018
# 2016-10-02  0.2565  0.3453  0.2580  0.8609  0.2617  0.6517  0.7415  0.7165
# 2016-10-18  0.4343  0.2672  0.1231  0.4158  0.2417  0.5646  0.7165  0.6857
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2020-06-23  0.4312  0.2010  0.8888  0.6866  0.8136  0.9078  0.9173  0.8811
# 2020-07-09  0.8457  0.2464  0.9322  0.9043  0.5422  0.8959  0.8993  0.8627
# 2020-07-25  0.9276  0.3010  0.9308  0.9239  0.2719  0.8819  0.8940  0.8577
# 2020-08-10  0.9260  0.3618  0.9212  0.9176  0.2863  0.8693  0.8736  0.8218
# 2020-08-26  0.8649  0.7129  0.8588  0.8225  0.5603  0.8227  0.8348  0.7321
#
# date            9       10  ...      21      22      23      24      25  \
# 2016-08-15  0.8353  0.4327  ...  0.7019  0.3365  0.2500  0.7232  0.2735
# 2016-08-31  0.2974  0.2854  ...  0.2367  0.6333  0.2535  0.8153  0.5234
# 2016-09-16  0.3784  0.2164  ...  0.2014  0.1659  0.1715  0.5327  0.2254
# 2016-10-02  0.5940  0.2424  ...  0.1787  0.1297  0.2627  0.2618  0.2630
# 2016-10-18  0.2869  0.2731  ...  0.1436  0.3849  0.2705  0.2782  0.2384
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# 2020-06-23  0.2884  0.8759  ...  0.4539  0.7484  0.9153  0.8307  0.2738
# 2020-07-09  0.2494  0.8775  ...  0.7898  0.8667  0.9151  0.6298  0.4040
# 2020-07-25  0.3743  0.8645  ...  0.9068  0.9057  0.9058  0.2922  0.6531
# 2020-08-10  0.8511  0.8459  ...  0.9185  0.6013  0.8968  0.4350  0.8327
# 2020-08-26  0.9088  0.8214  ...  0.8899  0.8592  0.8631  0.6420  0.8492
#
# date            26      27      28      29      30
# 2016-08-15  0.2335  0.2147  0.5379  0.3726  0.3243
# 2016-08-31  0.2182  0.7428  0.7299  0.2382  0.1839
# 2016-09-16  0.2226  0.7934  0.4309  0.1410  0.2529
# 2016-10-02  0.2122  0.7703  0.8174  0.2067  0.2314
# 2016-10-18  0.2038  0.2300  0.3020  0.1834  0.2160
# ...            ...     ...     ...     ...     ...
# 2020-06-23  0.4702  0.4783  0.4063  0.3615  0.4475
# 2020-07-09  0.8197  0.8161  0.7542  0.2432  0.8760
# 2020-07-25  0.9220  0.9146  0.8672  0.3952  0.9178
# 2020-08-10  0.9146  0.9229  0.8629  0.6907  0.9244
# 2020-08-26  0.7681  0.9071  0.8399  0.8813  0.9011
#
# [93 rows x 30 columns]

# %%
anos_ag = {'2016':[date(2016, 9, 1), date(2017, 8, 31)],
           '2017':[date(2017, 9, 1), date(2018, 8, 31)],
           '2018':[date(2018, 9, 1), date(2019, 8, 31)],
           '2019':[date(2019, 9, 1), date(2020, 8, 31)]}

# %%
for i in range(1,int(df.shape[1]/2)+1):
    
    fig, ax = plt.subplots(1,len(anos_ag),figsize=(18,3),sharey=True)
    fig.subplots_adjust(wspace = .03)
    
    for axs, (ano, intervalo) in zip(ax.flat, anos_ag.items()):
        axs.set_ylim(0,1)
    
        months = mdates.MonthLocator(interval=3)
        month_fmt = mdates.DateFormatter('%b/%y')
        
        axs.get_xaxis().set_major_locator(months)
        axs.get_xaxis().set_major_formatter(month_fmt)
               
        axs.set_title(ano,weight='bold')
        
        if axs == ax.flat[0]:
            axs.set_ylabel('Ponto {}'.format(i),labelpad=10,weight='bold')
        
        axs.plot(df.loc[intervalo[0]:intervalo[1],i],marker='.');

# %%
for i in range(int(df.shape[1]/2)+1,df.shape[1]+1):
    
    fig, ax = plt.subplots(1,len(anos_ag),figsize=(18,3),sharey=True)
    fig.subplots_adjust(wspace = .03)
    
    for axs, (ano, intervalo) in zip(ax.flat, anos_ag.items()):
        axs.set_ylim(0,1)
    
        months = mdates.MonthLocator(interval=3)
        month_fmt = mdates.DateFormatter('%b/%y')
        
        axs.get_xaxis().set_major_locator(months)
        axs.get_xaxis().set_major_formatter(month_fmt)
               
        axs.set_title(ano,weight='bold')
        
        if axs == ax.flat[0]:
            axs.set_ylabel('Ponto {}'.format(i),labelpad=10,weight='bold')
        
        axs.plot(df.loc[intervalo[0]:intervalo[1],i],marker='.');
